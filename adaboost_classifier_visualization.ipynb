# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
# load iris dataset
from sklearn.datasets import load_iris

# %%
iris = load_iris()
# feature names
features_name = iris.feature_names
#target names
target_name = iris.target_names

# %%
# load required library
import numpy as np
from sklearn.datasets import load_iris
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import  plot_tree

# %%
def plot_decision_trees(clf, iteration, feature_name, target_name):
    plt.figure(figsize=[4.0,5.0])
    plot_tree(clf, filled=True, feature_names=feature_name, class_names=target_name, node_ids=True)
    plt.show()
    print("Decision Tree {}".format(iteration + 1))

# %%
model = AdaBoostClassifier(n_estimators=5)
model.fit(iris.data, iris.target)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=1.0,
#                    n_estimators=5, random_state=None)

# %%
model.estimators_
# Out:
# [DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#                         max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=492281511, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#                         max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1373514822, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#                         max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=14952964, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#                         max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1284917609, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#                         max_features=None, max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1864026154, splitter='best')]

# %%
model.estimators_[0]
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=492281511, splitter='best')

# %%
len(model.estimators_)
# Out:
# 5

# %%
for i in range(len(model.estimators_)):
    plot_decision_trees(model.estimators_[i], i, features_name, target_name)
# Out:
# Decision Tree 1
# Decision Tree 2
# Decision Tree 3
# Decision Tree 4
# Decision Tree 5
